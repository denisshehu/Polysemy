# %%
import numpy as np

from models.point_cloud import *
import methods.intrinsic_dimension_estimators.pid as pid
import methods.intrinsic_dimension_estimators.danco as danco

# %%
n1, n2 = 1000, 100
intrinsic_dimension1, intrinsic_dimension2 = 3, 2
r1, r2 = 1, 1
spatial_dimension = 3

# %%
points = sample_from_intersecting_spheres(n1, intrinsic_dimension1, r1, n2, intrinsic_dimension2, r2, spatial_dimension)

# %%
point_cloud = PointCloud()
point_cloud.random_constructor(points, (n1 + n2))

# %%
# pid.estimate(point_cloud, 10, 3, 1)

# %%
danco.estimate(point_cloud, 10, 20)

# %%
visualize_dimension(point_cloud, 'test', advanced=False)
