# %%
from models.point_cloud import *
from methods.gad import detect as old
from other.gad3 import detect as new

# %%
k = 100

# %%
n1, n2 = 10000, 10000
r1, r2 = 1, 1
seed1, seed2 = 1, 1

# %%
points = sample_from_intersecting_planes(n1, r1, n2, r2, seed1, seed2)

# %%
plot_3d_scatterplot(points, points[:, 0], None, 'A', 30, 30, None, False, False, False, None)

# %%
point_cloud = PointCloud()
point_cloud.random_constructor(points, len(points), 1)

# %%
for query in point_cloud.queries:
    query.intrinsic_dimension = 2.0

# %%
new(point_cloud, k)

# %%
queries = [query for query in point_cloud.queries if query.point[0] <= 0]

# %%
data = np.array([query.point for query in queries])
c = [query.classification for query in queries]

# %%
for i in range(len(c)):
    if c[i] == 'boundary':
        c[i] = 0
    if c[i] == 'regular':
        c[i] = 1
    if c[i] == 'singular':
        c[i] = 2

# %%
plot_3d_scatterplot(data, c, None, 'A', 30, 30, None, False, False, False, None)

# %%
t1 = [query._classification_estimates for query in point_cloud.queries]

# %%
detect(point_cloud, k, n_steps=5)

# %%
queries = [query for query in point_cloud.queries if query.point[0] <= 0]

# %%
data = np.array([query.point for query in queries])
c = [query.classification for query in queries]

# %%
for i in range(len(c)):
    if c[i] == 'boundary':
        c[i] = 0
    if c[i] == 'regular':
        c[i] = 1
    if c[i] == 'singular':
        c[i] = 2

# %%
plot_3d_scatterplot(data, c, None, 'A', 30, 30, None, False, False, False, None)

# %%
t2 = [query._classification_estimates for query in point_cloud.queries]

# %%
t1[0]

# %%
t2[0]

# %%
t1 == t2
