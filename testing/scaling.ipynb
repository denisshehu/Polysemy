# %%
from utils.main import *
from visualization_generation.plots import *

# %%
n = 100
intrinsic_dimension = 2
max_r = 3
min_r = 2
seed = None
spatial_dimension = intrinsic_dimension + 1

# %%
points = sample_from_annulus(n, intrinsic_dimension, max_r, min_r, seed, spatial_dimension)

# %%
plot_2d(points)

# %%
not_centered = translate(points, np.array([-2, -3, 0]))

# %%
vector = np.array([2, 3, 0])

# %%
plot_2d(not_centered)

# %%
plot_2d(translate(not_centered, vector))

# %%
plot_2d(project_to_unit_circle(not_centered, vector))
